# %%
from sportsreference.nfl.teams import Teams

teams = Teams()
for team in teams:
    print(team.name)
# Out:
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?

# %%
from sportsreference.ncaab.schedule import Schedule

purdue_schedule = Schedule('purdue')
for game in purdue_schedule:
    print(game.date)
# Out:
# Tue, Nov 9, 2021
# Fri, Nov 12, 2021
# Tue, Nov 16, 2021
# Sat, Nov 20, 2021
# Sun, Nov 21, 2021
# Fri, Nov 26, 2021
# Tue, Nov 30, 2021
# Fri, Dec 3, 2021
# Thu, Dec 9, 2021
# Sun, Dec 12, 2021
# Sat, Dec 18, 2021
# Mon, Dec 20, 2021
# Wed, Dec 29, 2021
# Mon, Jan 3, 2022
# Sat, Jan 8, 2022
# Fri, Jan 14, 2022
# Mon, Jan 17, 2022
# Thu, Jan 20, 2022
# Sun, Jan 23, 2022
# Thu, Jan 27, 2022
# Sun, Jan 30, 2022
# Wed, Feb 2, 2022
# Sat, Feb 5, 2022
# Tue, Feb 8, 2022
# Thu, Feb 10, 2022
# Sun, Feb 13, 2022
# Wed, Feb 16, 2022
# Sun, Feb 20, 2022
# Sat, Feb 26, 2022
# Tue, Mar 1, 2022
# Sat, Mar 5, 2022
# Fri, Mar 11, 2022
# Sat, Mar 12, 2022
# Sun, Mar 13, 2022
# Fri, Mar 18, 2022
# Sun, Mar 20, 2022
# Fri, Mar 25, 2022

# %%
from sportsreference.nfl.teams import Teams

teams = Teams()
lions = teams('SFO')
# Out:
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\andre\Documents\Strive_repository\Predicting_nfl_games\data\test_data.ipynb Cella 3 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/Strive_repository/Predicting_nfl_games/data/test_data.ipynb#ch0000002?line=0'>1</a> from sportsreference.nfl.teams import Teams
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/Strive_repository/Predicting_nfl_games/data/test_data.ipynb#ch0000002?line=2'>3</a> teams = Teams()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/Strive_repository/Predicting_nfl_games/data/test_data.ipynb#ch0000002?line=3'>4</a> lions = teams('SFO')
#
# File c:\Users\andre\Documents\Strive_repository\Predicting_nfl_games\env\lib\site-packages\sportsreference\nfl\teams.py:587, in Teams.__call__(self, abbreviation)
#     569 def __call__(self, abbreviation):
#     570     """
#     571     Return a specified team.
#     572
#    (...)
#     585         If the requested team can be found, its Team instance is returned.
#     586     """
# --> 587     return self.__getitem__(abbreviation)
#
# File c:\Users\andre\Documents\Strive_repository\Predicting_nfl_games\env\lib\site-packages\sportsreference\nfl\teams.py:567, in Teams.__getitem__(self, abbreviation)
#     565     if team.abbreviation.upper() == abbreviation.upper():
#     566         return team
# --> 567 raise ValueError('Team abbreviation %s not found' % abbreviation)
#
# ValueError: Team abbreviation SFO not found

# %%
from sportsreference.nfl.boxscore import Boxscores, Boxscore
Boxscores(1,2021).games
# Out:
# {'1-2021': [{'boxscore': '202109090tam',
#    'away_name': 'Dallas Cowboys',
#    'away_abbr': 'dal',
#    'away_score': 29,
#    'home_name': 'Tampa Bay Buccaneers',
#    'home_abbr': 'tam',
#    'home_score': 31,
#    'winning_name': 'Tampa Bay Buccaneers',
#    'winning_abbr': 'tam',
#    'losing_name': 'Dallas Cowboys',
#    'losing_abbr': 'dal'},
#   {'boxscore': '202109120atl',
#    'away_name': 'Philadelphia Eagles',
#    'away_abbr': 'phi',
#    'away_score': 32,
#    'home_name': 'Atlanta Falcons',
#    'home_abbr': 'atl',
#    'home_score': 6,
#    'winning_name': 'Philadelphia Eagles',
#    'winning_abbr': 'phi',
#    'losing_name': 'Atlanta Falcons',
#    'losing_abbr': 'atl'},
#   {'boxscore': '202109120buf',
#    'away_name': 'Pittsburgh Steelers',
#    'away_abbr': 'pit',
#    'away_score': 23,
#    'home_name': 'Buffalo Bills',
#    'home_abbr': 'buf',
#    'home_score': 16,
#    'winning_name': 'Pittsburgh Steelers',
#    'winning_abbr': 'pit',
#    'losing_name': 'Buffalo Bills',
#    'losing_abbr': 'buf'},
#   {'boxscore': '202109120car',
#    'away_name': 'New York Jets',
#    'away_abbr': 'nyj',
#    'away_score': 14,
#    'home_name': 'Carolina Panthers',
#    'home_abbr': 'car',
#    'home_score': 19,
#    'winning_name': 'Carolina Panthers',
#    'winning_abbr': 'car',
#    'losing_name': 'New York Jets',
#    'losing_abbr': 'nyj'},
#   {'boxscore': '202109120cin',
#    'away_name': 'Minnesota Vikings',
#    'away_abbr': 'min',
#    'away_score': 24,
#    'home_name': 'Cincinnati Bengals',
#    'home_abbr': 'cin',
#    'home_score': 27,
#    'winning_name': 'Cincinnati Bengals',
#    'winning_abbr': 'cin',
#    'losing_name': 'Minnesota Vikings',
#    'losing_abbr': 'min'},
#   {'boxscore': '202109120clt',
#    'away_name': 'Seattle Seahawks',
#    'away_abbr': 'sea',
#    'away_score': 28,
#    'home_name': 'Indianapolis Colts',
#    'home_abbr': 'clt',
#    'home_score': 16,
#    'winning_name': 'Seattle Seahawks',
#    'winning_abbr': 'sea',
#    'losing_name': 'Indianapolis Colts',
#    'losing_abbr': 'clt'},
#   {'boxscore': '202109120det',
#    'away_name': 'San Francisco 49ers',
#    'away_abbr': 'sfo',
#    'away_score': 41,
#    'home_name': 'Detroit Lions',
#    'home_abbr': 'det',
#    'home_score': 33,
#    'winning_name': 'San Francisco 49ers',
#    'winning_abbr': 'sfo',
#    'losing_name': 'Detroit Lions',
#    'losing_abbr': 'det'},
#   {'boxscore': '202109120htx',
#    'away_name': 'Jacksonville Jaguars',
#    'away_abbr': 'jax',
#    'away_score': 21,
#    'home_name': 'Houston Texans',
#    'home_abbr': 'htx',
#    'home_score': 37,
#    'winning_name': 'Houston Texans',
#    'winning_abbr': 'htx',
#    'losing_name': 'Jacksonville Jaguars',
#    'losing_abbr': 'jax'},
#   {'boxscore': '202109120oti',
#    'away_name': 'Arizona Cardinals',
#    'away_abbr': 'crd',
#    'away_score': 38,
#    'home_name': 'Tennessee Titans',
#    'home_abbr': 'oti',
#    'home_score': 13,
#    'winning_name': 'Arizona Cardinals',
#    'winning_abbr': 'crd',
#    'losing_name': 'Tennessee Titans',
#    'losing_abbr': 'oti'},
#   {'boxscore': '202109120was',
#    'away_name': 'Los Angeles Chargers',
#    'away_abbr': 'sdg',
#    'away_score': 20,
#    'home_name': 'Washington Football Team',
#    'home_abbr': 'was',
#    'home_score': 16,
#    'winning_name': 'Los Angeles Chargers',
#    'winning_abbr': 'sdg',
#    'losing_name': 'Washington Football Team',
#    'losing_abbr': 'was'},
#   {'boxscore': '202109120kan',
#    'away_name': 'Cleveland Browns',
#    'away_abbr': 'cle',
#    'away_score': 29,
#    'home_name': 'Kansas City Chiefs',
#    'home_abbr': 'kan',
#    'home_score': 33,
#    'winning_name': 'Kansas City Chiefs',
#    'winning_abbr': 'kan',
#    'losing_name': 'Cleveland Browns',
#    'losing_abbr': 'cle'},
#   {'boxscore': '202109120nor',
#    'away_name': 'Green Bay Packers',
#    'away_abbr': 'gnb',
#    'away_score': 3,
#    'home_name': 'New Orleans Saints',
#    'home_abbr': 'nor',
#    'home_score': 38,
#    'winning_name': 'New Orleans Saints',
#    'winning_abbr': 'nor',
#    'losing_name': 'Green Bay Packers',
#    'losing_abbr': 'gnb'},
#   {'boxscore': '202109120nwe',
#    'away_name': 'Miami Dolphins',
#    'away_abbr': 'mia',
#    'away_score': 17,
#    'home_name': 'New England Patriots',
#    'home_abbr': 'nwe',
#    'home_score': 16,
#    'winning_name': 'Miami Dolphins',
#    'winning_abbr': 'mia',
#    'losing_name': 'New England Patriots',
#    'losing_abbr': 'nwe'},
#   {'boxscore': '202109120nyg',
#    'away_name': 'Denver Broncos',
#    'away_abbr': 'den',
#    'away_score': 27,
#    'home_name': 'New York Giants',
#    'home_abbr': 'nyg',
#    'home_score': 13,
#    'winning_name': 'Denver Broncos',
#    'winning_abbr': 'den',
#    'losing_name': 'New York Giants',
#    'losing_abbr': 'nyg'},
#   {'boxscore': '202109120ram',
#    'away_name': 'Chicago Bears',
#    'away_abbr': 'chi',
#    'away_score': 14,
#    'home_name': 'Los Angeles Rams',
#    'home_abbr': 'ram',
#    'home_score': 34,
#    'winning_name': 'Los Angeles Rams',
#    'winning_abbr': 'ram',
#    'losing_name': 'Chicago Bears',
#    'losing_abbr': 'chi'},
#   {'boxscore': '202109130rai',
#    'away_name': 'Baltimore Ravens',
#    'away_abbr': 'rav',
#    'away_score': 27,
#    'home_name': 'Las Vegas Raiders',
#    'home_abbr': 'rai',
#    'home_score': 33,
#    'winning_name': 'Las Vegas Raiders',
#    'winning_abbr': 'rai',
#    'losing_name': 'Baltimore Ravens',
#    'losing_abbr': 'rav'}]}
